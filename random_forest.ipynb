# %%
from sklearn.ensemble import RandomForestRegressor
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV, train_test_split
# Following tutorial: https://medium.com/@prathik.codes/mastering-randomforestregressor-in-scikit-learn-a-practical-guide-ba8615097100
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams.update({"figure.dpi": 200})
sns.set_theme(style='ticks')

# %%
test_results = pd.read_csv('stat_test_results.csv')

# %%
# Find locations where Kruskall-Wallis test was significant
# These should be the most important locations to look at when deciding flowering time
cols = test_results.loc[test_results['corrected_pval'] < 0.01,'location'].to_list()

# %%
data = pd.read_csv('processed.csv', index_col=0, header=None).transpose().astype({'5_FT10':np.float64})

# %%
# Filter dataset to only include significant SNPs and flowering time
data = data[['5_FT10']+cols]
data
# Out:
# 0    5_FT10 1:3877554 5:3188327 2:9581605 2:9604507 1:3849924 2:13618247  \
# 1     100.0         G         T         C         C         A          A
# 2      96.3         G         C         C         C         A          A
# 3     100.0         G         T         C         C         A          A
# 4      60.5         A         C         G         A         T          G
# 5      98.0         A         T         G         A         T          A
# ..      ...       ...       ...       ...       ...       ...        ...
# 226   100.0         G         T         G         A         A          A
# 227    90.7         G         T         G         A         A          G
# 228    86.0         G         C         G         A         A          A
# 229   105.0         G         T         C         C         A          A
# 230   107.0         G         T         C         C         A          A
#
# 0   1:3840597 1:3844044 1:3872387  ... 4:16102433 2:13146146 1:3860220  \
# 1           C         T         G  ...          C          G         T
# 2           C         T         G  ...          C          G         T
# 3           C         T         G  ...          C          G         T
# 4           T         G         A  ...          T          A         A
# 5           T         G         A  ...          C          A         A
# ..        ...       ...       ...  ...        ...        ...       ...
# 226         C         T         G  ...          T          A         T
# 227         C         T         G  ...          T          A         T
# 228         C         T         G  ...          C          G         T
# 229         C         T         G  ...          C          G         T
# 230         C         T         G  ...          C          A         T
#
# 0   1:24329671 5:26945835 5:18601034 1:19618944 5:3054187 1:30175419  \
# 1            A          A          T          C         G          G
# 2            A          A          T          C         A          G
# 3            A          G          C          T         G          G
# 4            A          A          T          T         A          C
# 5            T          G          C          C         A          G
# ..         ...        ...        ...        ...       ...        ...
# 226          A          G          C          T         A          G
# 227          A          A          C          C         G          G
# 228          A          G          C          T         A          G
# 229          A          G          C          T         G          G
# 230          A          G          C          T         G          G
#
# 0   3:20197802
# 1            A
# 2            A
# 3            A
# 4            C
# 5            A
# ..         ...
# 226          A
# 227          A
# 228          A
# 229          A
# 230          A
#
# [230 rows x 1372 columns]

# %%
train, test = train_test_split(data, test_size=0.1, random_state=42)
X_train = train.iloc[:,1:]
X_test = test.iloc[:,1:]
enc = preprocessing.OneHotEncoder(drop='if_binary')
X_train = enc.fit_transform(X_train)
X_test = enc.transform(X_test)

y_train = train['5_FT10']
y_test = test['5_FT10']

# %%
# Random forest with default parameters
base_rf = RandomForestRegressor(
    random_state=42,
    n_jobs=-1,
)

base_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
y_pred = base_rf.predict(X_test)
print(mean_squared_error(y_test, y_pred))
# Out:
# 116.42606039130433

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7558011157411163

# %%
# Optimizing the model using gridsearchCV
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
param_grid = {
    'max_features': ['sqrt', 'log2', None],
    'n_estimators': [10, 100, 1000],
    'max_depth': [10, 100, 1000, None],
}
rf = RandomForestRegressor(random_state=42, n_jobs=-1)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, verbose=2)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END .max_depth=10, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END .max_depth=10, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END .max_depth=10, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END .max_depth=10, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END .max_depth=10, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END ...max_depth=10, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END ...max_depth=10, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END ...max_depth=10, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END ...max_depth=10, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END ...max_depth=10, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END .max_depth=10, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END .max_depth=10, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END .max_depth=10, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END .max_depth=10, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END .max_depth=10, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END ...max_depth=10, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END ...max_depth=10, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END ...max_depth=10, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END ...max_depth=10, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END ...max_depth=10, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END .max_depth=10, max_features=None, n_estimators=1000; total time=   1.9s
# [CV] END .max_depth=10, max_features=None, n_estimators=1000; total time=   1.9s
# [CV] END .max_depth=10, max_features=None, n_estimators=1000; total time=   1.8s
# [CV] END .max_depth=10, max_features=None, n_estimators=1000; total time=   2.0s
# [CV] END .max_depth=10, max_features=None, n_estimators=1000; total time=   1.9s
# [CV] END ..max_depth=100, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=100, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=100, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=100, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=100, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=100, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END .max_depth=100, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END .max_depth=100, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END .max_depth=100, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END .max_depth=100, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END max_depth=100, max_features=sqrt, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=100, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=100, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=100, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=100, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END ..max_depth=100, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=100, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=100, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=100, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=100, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=100, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END .max_depth=100, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END .max_depth=100, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END .max_depth=100, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END .max_depth=100, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=100, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=100, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=100, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=100, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=100, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END ..max_depth=100, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=100, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=100, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=100, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END ..max_depth=100, max_features=None, n_estimators=10; total time=   0.1s
# [CV] END .max_depth=100, max_features=None, n_estimators=100; total time=   0.3s
# [CV] END .max_depth=100, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END .max_depth=100, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END .max_depth=100, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END .max_depth=100, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END max_depth=100, max_features=None, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=100, max_features=None, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=100, max_features=None, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=100, max_features=None, n_estimators=1000; total time=   2.1s
# [CV] END max_depth=100, max_features=None, n_estimators=1000; total time=   2.0s
# [CV] END .max_depth=1000, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=1000, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=1000, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=1000, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=1000, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END max_depth=1000, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END max_depth=1000, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END max_depth=1000, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END max_depth=1000, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END max_depth=1000, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END max_depth=1000, max_features=sqrt, n_estimators=1000; total time=   0.4s
# [CV] END max_depth=1000, max_features=sqrt, n_estimators=1000; total time=   0.4s
# [CV] END max_depth=1000, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=1000, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=1000, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END .max_depth=1000, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=1000, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=1000, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=1000, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=1000, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=1000, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=1000, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=1000, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=1000, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=1000, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=1000, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=1000, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=1000, max_features=log2, n_estimators=1000; total time=   0.4s
# [CV] END max_depth=1000, max_features=log2, n_estimators=1000; total time=   0.4s
# [CV] END max_depth=1000, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END .max_depth=1000, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=1000, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=1000, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=1000, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=1000, max_features=None, n_estimators=10; total time=   0.1s
# [CV] END max_depth=1000, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END max_depth=1000, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END max_depth=1000, max_features=None, n_estimators=100; total time=   0.3s
# [CV] END max_depth=1000, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END max_depth=1000, max_features=None, n_estimators=100; total time=   0.3s
# [CV] END max_depth=1000, max_features=None, n_estimators=1000; total time=   2.1s
# [CV] END max_depth=1000, max_features=None, n_estimators=1000; total time=   2.3s
# [CV] END max_depth=1000, max_features=None, n_estimators=1000; total time=   2.1s
# [CV] END max_depth=1000, max_features=None, n_estimators=1000; total time=   2.1s
# [CV] END max_depth=1000, max_features=None, n_estimators=1000; total time=   1.9s
# [CV] END .max_depth=None, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=None, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=None, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=None, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=None, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=1000; total time=   0.3s
# [CV] END .max_depth=None, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=None, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=None, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=None, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=None, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, n_estimators=1000; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, n_estimators=1000; total time=   0.3s
# [CV] END .max_depth=None, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=None, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=None, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=None, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END .max_depth=None, max_features=None, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=None, n_estimators=1000; total time=   2.1s
# [CV] END max_depth=None, max_features=None, n_estimators=1000; total time=   2.0s
# [CV] END max_depth=None, max_features=None, n_estimators=1000; total time=   2.0s
# [CV] END max_depth=None, max_features=None, n_estimators=1000; total time=   2.1s
# [CV] END max_depth=None, max_features=None, n_estimators=1000; total time=   2.3s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(n_jobs=-1, random_state=42),
#              param_grid={'max_depth': [10, 100, 1000, None],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [10, 100, 1000]},
#              verbose=2)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 100, 'max_features': 'log2', 'n_estimators': 1000}

# %%
best_rf = grid_search.best_estimator_

# %%
best_y_pred = best_rf.predict(X_test)
print(f'MSE: {mean_squared_error(y_test, best_y_pred)}')
print(f'R^2: {r2_score(y_test, best_y_pred)}')
# Out:
# MSE: 116.19705075826015
# R^2: 0.7562814540492749

# %%
# Building model with full feature set
data_full = pd.read_csv('processed.csv', index_col=0, header=None).transpose().astype({'5_FT10':np.float64})
full_train, full_test = train_test_split(data_full, test_size=0.1, random_state=42)
full_X_train = full_train[full_train.columns[2:]]
full_X_test = full_test[full_test.columns[2:]]

# %%
categories = [['A', 'C', 'T', 'G'] for i in range(len(full_X_train.columns))]
enc_full = preprocessing.OneHotEncoder(categories=categories)
full_X_train = enc_full.fit_transform(full_X_train)
full_X_test = enc_full.transform(full_X_test)
full_y_train = full_train['5_FT10']
full_y_test = full_test['5_FT10']

# %%
base_rf_full = RandomForestRegressor(
    random_state=42,
    n_jobs=-1,
)

base_rf_full.fit(full_X_train, full_y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
y_pred_full = base_rf_full.predict(full_X_test)
print(f'MSE: {mean_squared_error(full_y_test, y_pred_full)}')
print(f'R^2: {r2_score(full_y_test, y_pred_full)}')
# base model using full feature set has pretty bad performance 
# and training time was long (about 4 minutes) so I don't think 
# it's worth it to optimize it.
# Out:
# MSE: 192.85431195652177
# R^2: 0.595495994230045

# %%
# Get highest relative importances of each feature in the reduced model and plot them
importances = pd.Series(best_rf.feature_importances_, train.columns[1:]).sort_values(ascending=False)
top_20 = importances[:20]

# %%
importance_plot = sns.barplot(x=top_20.values, y=top_20.index)
sns.despine()
importance_plot.set_ylabel('Location')
importance_plot.set_xlabel('Relative importance')
plt.show()

# %%
importance_df = pd.DataFrame({'location': top_20.index, 'importance': top_20.values})
importance_df['chromosome'] = importance_df['location'].map(lambda x: str.split(x,':')[0])
importance_df['position'] = importance_df['location'].map(lambda x: str.split(x,':')[1]).astype(int)
importance_df
# Out:
#       location  importance chromosome  position
# 0    5:3188327    0.005237          5   3188327
# 1    1:3877554    0.005071          1   3877554
# 2   2:13619418    0.004187          2  13619418
# 3    1:3874595    0.004157          1   3874595
# 4   2:13618247    0.003831          2  13618247
# 5    1:3881724    0.003599          1   3881724
# 6    1:3881063    0.003485          1   3881063
# 7    1:3855395    0.003472          1   3855395
# 8    2:8862404    0.003467          2   8862404
# 9    1:3880217    0.003362          1   3880217
# 10   1:3874948    0.003332          1   3874948
# 11   1:3978064    0.003313          1   3978064
# 12   1:3872522    0.003295          1   3872522
# 13   1:3872387    0.003286          1   3872387
# 14   2:9604507    0.003281          2   9604507
# 15   1:3873444    0.003200          1   3873444
# 16   1:3881520    0.003186          1   3881520
# 17   1:3841346    0.003134          1   3841346
# 18   1:3844044    0.003093          1   3844044
# 19   1:3840597    0.003041          1   3840597

# %%
# Compare these results to gene model
# Columns named according to: https://useast.ensembl.org/info/website/upload/gff.html
gff_names = ['Chr', 'source', 'feature', 'start', 'end', 'score', 'strand', 'frame', 'attribute']
gene_model = pd.read_table('gene_model.gff', sep='\t', header=None, names=gff_names)
gene_model['Chr'] = gene_model['Chr'].map(lambda x: str.replace(x, 'Chr', ''))
gene_model
# Out:
#        Chr  source     feature   start       end score strand frame  \
# 0        1  TAIR10  chromosome       1  30427671     .      .     .
# 1        1  TAIR10        gene    3631      5899     .      +     .
# 2        1  TAIR10        mRNA    3631      5899     .      +     .
# 3        1  TAIR10     protein    3760      5630     .      +     .
# 4        1  TAIR10        exon    3631      3913     .      +     .
# ...     ..     ...         ...     ...       ...   ...    ...   ...
# 590259   M  TAIR10        gene  366086    366700     .      -     .
# 590260   M  TAIR10        mRNA  366086    366700     .      -     .
# 590261   M  TAIR10     protein  366086    366700     .      -     .
# 590262   M  TAIR10         CDS  366086    366700     .      -     0
# 590263   M  TAIR10        exon  366086    366700     .      -     .
#
#                                                 attribute
# 0                                       ID=Chr1;Name=Chr1
# 1       ID=AT1G01010;Note=protein_coding_gene;Name=AT1...
# 2       ID=AT1G01010.1;Parent=AT1G01010;Name=AT1G01010...
# 3       ID=AT1G01010.1-Protein;Name=AT1G01010.1;Derive...
# 4                                      Parent=AT1G01010.1
# ...                                                   ...
# 590259  ID=ATMG01410;Note=protein_coding_gene;Name=ATM...
# 590260  ID=ATMG01410.1;Parent=ATMG01410;Name=ATMG01410...
# 590261  ID=ATMG01410.1-Protein;Name=ATMG01410.1;Derive...
# 590262            Parent=ATMG01410.1,ATMG01410.1-Protein;
# 590263                                 Parent=ATMG01410.1
#
# [590264 rows x 9 columns]

# %%
# Find genes that the most important SNPs are in
match_df = pd.DataFrame(columns=gene_model.columns.to_list() + ['SNP location'])
for i in importance_df.index:
    row = importance_df.loc[i,:]
    chrom = row['chromosome']
    position = row['position']
    matches = gene_model.loc[(gene_model['Chr'] == chrom) & (gene_model['start'] < position) & (gene_model['end'] > position) & (gene_model['feature'] != 'chromosome'),:].copy()
    if len(matches) > 0:
        matches.loc[:,'SNP location'] = [position] * len(matches)
        match_df = pd.concat([match_df, matches], axis='index')

match_df.reset_index(inplace=True, drop=True)

# %%
# Extract gene name from attribute column and remove genes that were matched multiple times before saving
match_df['gene name'] = match_df['attribute'].map(lambda x: str.split(x, ';')[0].split('=')[1])
match_df = match_df.sort_values(by=['Chr', 'start'])
match_df=match_df.loc[match_df['feature']=='gene'].drop_duplicates(subset=['start', 'end'])
match_df.loc[:,['Chr', 'start', 'end','SNP location', 'gene name']].to_csv('gene_annotations.csv', index=False)
